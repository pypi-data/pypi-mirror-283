# %% [markdown]
# # Simple arrow (vector/quiver) icon for folium
#
# This package provides simple arrow (vector/quiver) icon for the [folium](https://pypi.org/project/folium/) package.
#
# The arrow (vector/quiver) icon is independent of zoom level, its size does not change as zoom level changes.
# It is useful for displaying vector field.
#
# You can install `folium-arrow-icon` from PyPI:
#
# ```shell
# pip install folium-arrow-icon
# ```
#
# This packages is released under MIT licence.
#
# See [](#sample-code) for example.

# %% [markdown]
# ## Module contents
#
# ```{eval-rst}
# .. automodule:: folium_arrow_icon
#    :members:
#    :undoc-members:
#    :show-inheritance:
# ```

# %% [markdown]
# ## Sample Code

# %%
import math

import folium
from folium_arrow_icon import ArrowIcon

# %% [markdown]
# ### By length and angle

# %%
m = folium.Map(
    location=[40.78322, -73.96551],
    zoom_start=14,
    tiles='Cartodb Positron'
)

folium.Marker(
    [40.78322, -73.96551],
    icon=ArrowIcon(100, 0)
).add_to(m)

folium.Marker(
    [40.78322, -73.96551],
    icon=ArrowIcon(100, math.pi / 2, color="red")
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_143758f944a4c52cc416bf6d9304b606 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_143758f944a4c52cc416bf6d9304b606&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_143758f944a4c52cc416bf6d9304b606 = L.map(
#                 &quot;map_143758f944a4c52cc416bf6d9304b606&quot;,
#                 {
#                     center: [40.78322, -73.96551],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bd810ba573ee8aea5895492385ec6012 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bd810ba573ee8aea5895492385ec6012.addTo(map_143758f944a4c52cc416bf6d9304b606);
#
#
#             var marker_20fa2f502a3bd0b6f08f962f3e4fd3de = L.marker(
#                 [40.78322, -73.96551],
#                 {}
#             ).addTo(map_143758f944a4c52cc416bf6d9304b606);
#
#
#             var div_icon_5c8044fe1ad72025ed89ea68fef270e5 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003csvg xmlns=\&quot;http://www.w3.org/2000/svg\&quot; version=\&quot;1.1\&quot; viewBox=\&quot;-10 -110 21 120\&quot;\u003e\u003cg stroke=\&quot;black\&quot; fill=\&quot;black\&quot; stroke-width=\&quot;0\&quot; transform=\&quot;rotate(-90.0 0 0)\&quot;\u003e\u003cpath d=\&quot;M 0 -1 l 0 2 l 90 0 l 0 3 l 10 -4 l -10 -4 l 0 3 Z\&quot; /\u003e\u003c/g\u003e\u003c/svg\u003e&quot;, &quot;iconAnchor&quot;: [10, 110], &quot;iconSize&quot;: [21, 120]});
#             marker_20fa2f502a3bd0b6f08f962f3e4fd3de.setIcon(div_icon_5c8044fe1ad72025ed89ea68fef270e5);
#
#
#             var marker_0ac61ca746d627d129f6e09831abdbe9 = L.marker(
#                 [40.78322, -73.96551],
#                 {}
#             ).addTo(map_143758f944a4c52cc416bf6d9304b606);
#
#
#             var div_icon_8df3866b0be2e5c031a44102173ea15c = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003csvg xmlns=\&quot;http://www.w3.org/2000/svg\&quot; version=\&quot;1.1\&quot; viewBox=\&quot;-10 -10 120 20\&quot;\u003e\u003cg stroke=\&quot;red\&quot; fill=\&quot;red\&quot; stroke-width=\&quot;0\&quot; transform=\&quot;rotate(0.0 0 0)\&quot;\u003e\u003cpath d=\&quot;M 0 -1 l 0 2 l 90 0 l 0 3 l 10 -4 l -10 -4 l 0 3 Z\&quot; /\u003e\u003c/g\u003e\u003c/svg\u003e&quot;, &quot;iconAnchor&quot;: [10, 10], &quot;iconSize&quot;: [120, 20]});
#             marker_0ac61ca746d627d129f6e09831abdbe9.setIcon(div_icon_8df3866b0be2e5c031a44102173ea15c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### By components of latitude and longitude direction

# %%
m = folium.Map(
    location=[40.78322, -73.96551],
    zoom_start=14,
    tiles='Cartodb Positron'
)

folium.Marker(
    [40.78322, -73.96551],
    icon=ArrowIcon.from_comp((100, 50))
).add_to(m)

folium.Marker(
    [40.78322, -73.96551],
    icon=ArrowIcon.from_comp((-50, 100), color="red")
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6efea37233bfd97bf69e7d297db77786 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6efea37233bfd97bf69e7d297db77786&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6efea37233bfd97bf69e7d297db77786 = L.map(
#                 &quot;map_6efea37233bfd97bf69e7d297db77786&quot;,
#                 {
#                     center: [40.78322, -73.96551],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f21850dcc2809149e1f2725b26607cad = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f21850dcc2809149e1f2725b26607cad.addTo(map_6efea37233bfd97bf69e7d297db77786);
#
#
#             var marker_35d3aac297f6c535cb1843997fa55ce5 = L.marker(
#                 [40.78322, -73.96551],
#                 {}
#             ).addTo(map_6efea37233bfd97bf69e7d297db77786);
#
#
#             var div_icon_2df3b12041389b7d0a2677234eff77e5 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003csvg xmlns=\&quot;http://www.w3.org/2000/svg\&quot; version=\&quot;1.1\&quot; viewBox=\&quot;-10 -110 71 120\&quot;\u003e\u003cg stroke=\&quot;black\&quot; fill=\&quot;black\&quot; stroke-width=\&quot;0\&quot; transform=\&quot;rotate(-63.43494882292201 0 0)\&quot;\u003e\u003cpath d=\&quot;M 0 -1 l 0 2 l 101.8034 0 l 0 3 l 10 -4 l -10 -4 l 0 3 Z\&quot; /\u003e\u003c/g\u003e\u003c/svg\u003e&quot;, &quot;iconAnchor&quot;: [10, 110], &quot;iconSize&quot;: [71, 120]});
#             marker_35d3aac297f6c535cb1843997fa55ce5.setIcon(div_icon_2df3b12041389b7d0a2677234eff77e5);
#
#
#             var marker_81aa63704eaea5fb477377b41eb0dec1 = L.marker(
#                 [40.78322, -73.96551],
#                 {}
#             ).addTo(map_6efea37233bfd97bf69e7d297db77786);
#
#
#             var div_icon_b7ce2a61a2fdf71db087765094fb3fdb = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003csvg xmlns=\&quot;http://www.w3.org/2000/svg\&quot; version=\&quot;1.1\&quot; viewBox=\&quot;-10 -10 120 71\&quot;\u003e\u003cg stroke=\&quot;red\&quot; fill=\&quot;red\&quot; stroke-width=\&quot;0\&quot; transform=\&quot;rotate(26.565051177077994 0 0)\&quot;\u003e\u003cpath d=\&quot;M 0 -1 l 0 2 l 101.8034 0 l 0 3 l 10 -4 l -10 -4 l 0 3 Z\&quot; /\u003e\u003c/g\u003e\u003c/svg\u003e&quot;, &quot;iconAnchor&quot;: [10, 10], &quot;iconSize&quot;: [120, 71]});
#             marker_81aa63704eaea5fb477377b41eb0dec1.setIcon(div_icon_b7ce2a61a2fdf71db087765094fb3fdb);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Variation of anchor

# %%
from folium_arrow_icon import ArrowIconHead, ArrowIconBody

# %%
def marker(i: int, anchor: str, delta: float) -> folium.Marker:
    lat, lng = 40.78322, -73.96551
    return folium.Marker(
        # shif by (0.001 * i, delta) from (40.78322, -73.96551)
        [lat + 0.001 * i, lng + delta],
        icon=ArrowIcon(
            # wavy visualization
            150 + 50 * math.sin(i * math.pi / 20),
            math.pi / 2,
            # rainbowing by css property "hsl"
            color=f"hsl({i * 10}deg, 100%, 50%)",
            # show border of vector
            border_color="black",
            border_width=1,
            # big head
            head=ArrowIconHead(
                width=12,
                length=20
            ),
            # thin body relative to head
            body=ArrowIconBody(
                width=3
            ),
            # anchor is variable
            anchor=anchor
        )
    )

# %%
m = folium.Map(
    location=[40.78322 + 0.015, -73.96551 + 0.04],
    zoom_start=14,
    tiles='Cartodb Positron'
)

for i in range(36):
    # The left is anchor at 'tail' (default)
    marker(i, anchor="tail", delta=0.0).add_to(m)

    # The left is anchor at 'haed'
    marker(i, anchor="head", delta=0.04).add_to(m)

    # The left is anchor at 'mid'
    marker(i, anchor="mid", delta=0.06).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_473fbd166b6965d675deb985d78f0346 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_473fbd166b6965d675deb985d78f0346&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_473fbd166b6965d675deb985d78f0346 = L.map(
#                 &quot;map_473fbd166b6965d675deb985d78f0346&quot;,
#                 {
#                     center: [40.79822, -73.92550999999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_badca8de972f96b7cdebc80464490c0d = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_badca8de972f96b7cdebc80464490c0d.addTo(map_473fbd166b6965d675deb985d78f0346);
#
#
#             var marker_f123fe1c2d1c4a2f10bc81413bb69fd0 = L.marker(
#                 [40.78322, -73.96551],
#                 {}
#             ).addTo(map_473fbd166b6965d675deb985d78f0346);
#
#
#             var div_icon_86ce45575f6c94179e545e9f9b8458cb = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003csvg xmlns=\&quot;http://www.w3.org/2000/svg\&quot; version=\&quot;1.1\&quot; viewBox=\&quot;-20 -20 190 40\&quot;\u003e\u003cg stroke=\&quot;black\&quot; fill=\&quot;hsl(0deg, 100%, 50%)\&quot; stroke-width=\&quot;1\&quot; transform=\&quot;rotate(0.0 0 0)\&quot;\u003e\u003cpath d=\&quot;M 0 -1.5 l 0 3 l 130 0 l 0 4.5 l 20 -6 l -20 -6 l 0 4.5 Z\&quot; /\u003e\u003c/g\u003e\u003c/svg\u003e&quot;, &quot;iconAnchor&quot;: [20, 20], &quot;iconSize&quot;: [190, 40]});
#             marker_f123fe1c2d1c4a2f10bc81413bb69fd0.setIcon(div_icon_86ce45575f6c94179e545e9f9b8458cb);
#
#
#             var marker_2903dc991a62cda91e72761a52c0b553 = L.marker(
#                 [40.78322, -73.92550999999999],
#                 {}
#             ).addTo(map_473fbd166b6965d675deb985d78f0346);
#
#
#             var div_icon_1e34fea5c4309c5ef63cfde8e1dddae4 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003csvg xmlns=\&quot;http://www.w3.org/2000/svg\&quot; version=\&quot;1.1\&quot; viewBox=\&quot;-20 -20 190 40\&quot;\u003e\u003cg stroke=\&quot;black\&quot; fill=\&quot;hsl(0deg, 100%, 50%)\&quot; stroke-width=\&quot;1\&quot; transform=\&quot;rotate(0.0 0 0)\&quot;\u003e\u003cpath d=\&quot;M 0 -1.5 l 0 3 l 130 0 l 0 4.5 l 20 -6 l -20 -6 l 0 4.5 Z\&quot; /\u003e\u003c/g\u003e\u003c/svg\u003e&quot;, &quot;iconAnchor&quot;: [170.0, 20.0], &quot;iconSize&quot;: [190, 40]});
#             marker_2903dc991a62cda91e72761a52c0b553.setIcon(div_icon_1e34fea5c4309c5ef63cfde8e1dddae4);
#
#
#             var marker_b49e7266862677dd03a05668e47dc4b7 = L.marker(
#                 [40.78322, -73.90550999999999],
#                 {}
#             ).addTo(map_473fbd166b6965d675deb985d78f0346);
#
#
#             var div_icon_805c6c7de40c548e3f8311df5fb75560 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003csvg xmlns=\&quot;http://www.w3.org/2000/svg\&quot; version=\&quot;1.1\&quot; viewBox=\&quot;-20 -20 190 40\&quot;\u003e\u003cg stroke=\&quot;black\&quot; fill=\&quot;hsl(0deg, 100%, 50%)\&quot; stroke-width=\&quot;1\&quot; transform=\&quot;rotate(0.0 0 0)\&quot;\u003e\u003cpath d=\&quot;M 0 -1.5 l 0 3 l 130 0 l 0 4.5 l 20 -6 l -20 -6 l 0 4.5 Z\&quot; /\u003e\u003c/g\u003e\u003c/svg\u003e&quot;, &quot;iconAnchor&quot;: [95.0, 20.0], &quot;iconSize&quot;: [190, 40]});
#             marker_b49e7266862677dd03a05668e47dc4b7.setIcon(div_icon_805c6c7de40c548e3f8311df5fb75560);
#
#
#             var marker_5d9c25b9f4bd3ff057e1801a2d12a282 = L.marker(
#                 [40.78422, -73.96551],
#                 {}
#             ).addTo(map_473fbd166b6965d675deb985d78f0346);
#
#
#             var div_icon_18074f9cda6ce6436d13d383dce0d4ff = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003csvg xmlns=\&quot;http://www.w3.org/2000/svg\&quot; version=\&quot;1.1\&quot; viewBox=\&quot;-20 -20 198 40\&quot;\u003e\u003cg stroke=\&quot;black\&quot; fill=\&quot;hsl(10deg, 100%, 50%)\&quot; stroke-width=\&quot;1\&quot; transform=\&quot;rotate(0.0 0 0)\&quot;\u003e\u003cpath d=\&quot;M 0 -1.5 l 0 3 l 137.8217 0 l 0 4.5 l 20 -6 l -20 -6 l 0 4.5 Z\&quot; /\u003e\u003c/g\u003e\u003c/svg\u003e&quot;, &quot;iconAnchor&quot;: [20, 20], &quot;iconSize&quot;: [198, 40]});
#             marker_5d9c25b9f4bd3ff057e1801a2d12a282.setIcon(div_icon_18074f9cda6ce6436d13d383dce0d4ff);
#
#
#             var marker_b24d633454aaddd7b2c84292cba99366 = L.marker(
#                 [40.78422, -73.92550999999999],
#                 {}
#             ).addTo(map_473fbd166b6965d675deb985d78f0346);
#
#
#             var div_icon_63fce876d28fa8b0faca1c9a902569d3 = L.divIcon({&quot;classN

# %% [markdown]
# ## Indices and tables
#
# * {ref}`genindex`
# * {ref}`modindex`
# * {ref}`search`
